# %% [markdown]
# ## Task-3

# %% [markdown]
# ## load the data

# %%
import zipfile

with zipfile.ZipFile("bank+marketing.zip", "r") as zip_ref:
    zip_ref.extractall("bank_marketing")

print("Extraction completed!")
# Out:
# Extraction completed!

# %%
import os

print(os.listdir("bank_marketing"))
# Out:
# ['bank-additional.zip', 'bank.zip']

# %%
import zipfile

with zipfile.ZipFile("bank_marketing/bank.zip", "r") as zip_ref:
    zip_ref.extractall("bank_marketing/bank")

print("bank.zip extracted successfully!")
# Out:
# bank.zip extracted successfully!

# %%
import os

print(os.listdir("bank_marketing/bank"))
# Out:
# ['bank-full.csv', 'bank-names.txt', 'bank.csv']

# %%
import pandas as pd

df = pd.read_csv("bank_marketing/bank/bank-full.csv", sep=";")

df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %% [markdown]
# ## the shape of the data

# %%
df.shape
# Out:
# (45211, 17)

# %% [markdown]
# ## Display column names

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='str')

# %% [markdown]
# ## Dataset information

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  str
#  2   marital    45211 non-null  str
#  3   education  45211 non-null  str
#  4   default    45211 non-null  str
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  str
#  7   loan       45211 non-null  str
#  8   contact    45211 non-null  str
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  str
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  str
#  16  y          45211 non-null  str
# dtypes: int64(7), str(10)
# memory usage: 5.9 MB

# %% [markdown]
# ## Check for missing values

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# ## Statistical summary

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %% [markdown]
# ## customer Age Distribution

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df["age"], bins=20)

plt.title("Customer Age Distribution")
plt.xlabel("Age")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ## Display the Last Five Records

# %%
df.tail()
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 45206   cellular   17   nov       977         3     -1         0  unknown  yes
# 45207   cellular   17   nov       456         2     -1         0  unknown  yes
# 45208   cellular   17   nov      1127         5    184         3  success  yes
# 45209  telephone   17   nov       508         4     -1         0  unknown   no
# 45210   cellular   17   nov       361         2    188        11    other   no

# %% [markdown]
# ## Count Total Missing Values

# %%
print("Total Missing Values:", df.isnull().sum().sum())
# Out:
# Total Missing Values: 0

# %% [markdown]
# ## Generate Statistical Summary

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %% [markdown]
# ## Generate Statistical Summary for All Columns

# %%
df.describe(include="all")
# Out:
#                  age          job  marital  education default        balance  \
# count   45211.000000        45211    45211      45211   45211   45211.000000
# unique           NaN           12        3          4       2            NaN
# top              NaN  blue-collar  married  secondary      no            NaN
# freq             NaN         9732    27214      23202   44396            NaN
# mean       40.936210          NaN      NaN        NaN     NaN    1362.272058
# std        10.618762          NaN      NaN        NaN     NaN    3044.765829
# min        18.000000          NaN      NaN        NaN     NaN   -8019.000000
# 25%        33.000000          NaN      NaN        NaN     NaN      72.000000
# 50%        39.000000          NaN      NaN        NaN     NaN     448.000000
# 75%        48.000000          NaN      NaN        NaN     NaN    1428.000000
# max        95.000000          NaN      NaN        NaN     NaN  102127.000000
#
# ...

# %% [markdown]
# ## Display the Number of Unique Values

# %%
df.nunique()
# Out:
# age            77
# job            12
# marital         3
# education       4
# default         2
# balance      7168
# housing         2
# loan            2
# contact         3
# day            31
# month          12
# duration     1573
# campaign       48
# pdays         559
# previous       41
# poutcome        4
# y               2
# dtype: int64

# %% [markdown]
# # Find Duplicate Records

# %%
print("Duplicate Records:", df.duplicated().sum())
# Out:
# Duplicate Records: 0

# %% [markdown]
# ## Remove Duplicate Records

# %%
df = df.drop_duplicates()

print("Duplicates Removed Successfully")
# Out:
# Duplicates Removed Successfully

# %% [markdown]
# # Display the Size of the Dataset

# %%
print("Dataset Size:", df.size)
# Out:
# Dataset Size: 768587

# %% [markdown]
# # Display the Dimensions of the Dataset

# %%
print("Dimensions:", df.ndim)
# Out:
# Dimensions: 2

# %% [markdown]
# # Display a Random Sample of Records

# %%
df.sample(10)
# Out:
#        age            job   marital  education default  balance housing loan  \
# 35085   26    blue-collar   married  secondary      no        0     yes   no
# 33641   29       services   married  secondary      no        0     yes  yes
# 6431    31     management   married   tertiary      no    22867     yes   no
# 8607    43    blue-collar   married    primary      no        0     yes   no
# 15032   37  self-employed   married  secondary     yes        0     yes   no
# 24074   32     technician    single   tertiary      no     5514      no   no
# 530     44    blue-collar   married    primary      no      213      no   no
# 35924   38     technician  divorced  secondary      no      566     yes   no
# 8550    35    blue-collar   married    unknown      no       56     yes   no
# 31139   30     technician    single   tertiary      no      985     yes   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %% [markdown]
# # Display Customer Age Details

# %%
print(df["age"])
# Out:
# 0        58
# 1        44
# 2        33
# 3        47
# 4        33
#          ..
# 45206    51
# 45207    71
# 45208    72
# 45209    57
# 45210    37
# Name: age, Length: 45211, dtype: int64

# %% [markdown]
# # Find Minimum, Maximum and Average Age

# %%
print("Minimum Age:", df["age"].min())
print("Maximum Age:", df["age"].max())
print("Average Age:", df["age"].mean())
# Out:
# Minimum Age: 18
# Maximum Age: 95
# Average Age: 40.93621021432837

# %% [markdown]
# # Display All Unique Job Categories

# %%
print(df["job"].unique())
# Out:
# <StringArray>
# [   'management',    'technician',  'entrepreneur',   'blue-collar',
#        'unknown',       'retired',        'admin.',      'services',
#  'self-employed',    'unemployed',     'housemaid',       'student']
# Length: 12, dtype: str

# %% [markdown]
# # Count Customers in Each Job Category

# %%
print(df["job"].value_counts())
# Out:
# job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: count, dtype: int64

# %% [markdown]
# # Display Unique Education Levels

# %%
print(df["education"].unique())
# Out:
# <StringArray>
# ['tertiary', 'secondary', 'unknown', 'primary']
# Length: 4, dtype: str

# %% [markdown]
# # Count Customers by Marital Status

# %%
print(df["marital"].value_counts())
# Out:
# marital
# married     27214
# single      12790
# divorced     5207
# Name: count, dtype: int64

# %% [markdown]
# # Count Customers Having Housing Loan

# %%
print(df["housing"].value_counts())
# Out:
# housing
# yes    25130
# no     20081
# Name: count, dtype: int64

# %% [markdown]
# # Count Customers Having Personal Loan

# %%
print(df["loan"].value_counts())
# Out:
# loan
# no     37967
# yes     7244
# Name: count, dtype: int64

# %% [markdown]
# # Count Customers with Credit Default

# %%
print(df["default"].value_counts())
# Out:
# default
# no     44396
# yes      815
# Name: count, dtype: int64

# %% [markdown]
# # Count Customers by Contact Method

# %%
print(df["contact"].value_counts())
# Out:
# contact
# cellular     29285
# unknown      13020
# telephone     2906
# Name: count, dtype: int64

# %% [markdown]
# # Count Customers by Campaign Month

# %%
print(df["month"].value_counts())
# Out:
# month
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# feb     2649
# jan     1403
# oct      738
# sep      579
# mar      477
# dec      214
# Name: count, dtype: int64

# %% [markdown]
# # Count Customers Who Subscribed to a Term Deposit

# %%
print(df["y"].value_counts())
# Out:
# y
# no     39922
# yes     5289
# Name: count, dtype: int64

# %% [markdown]
# # Find the Average Account Balance

# %%
print("Average Balance:", df["balance"].mean())
# Out:
# Average Balance: 1362.2720576850766

# %% [markdown]
# # Display the Top 10 Customers with the Highest Balance

# %%
print(df.nlargest(10, "balance"))
# Out:
#        age           job   marital  education default  balance housing loan  \
# 39989   51    management    single   tertiary      no   102127      no   no
# 26227   59    management   married   tertiary      no    98417      no   no
# 42558   84       retired   married  secondary      no    81204      no   no
# 43393   84       retired   married  secondary      no    81204      no   no
# 41693   60       retired   married    primary      no    71188      no   no
# 19785   56    management  divorced   tertiary      no    66721      no   no
# 21192   52   blue-collar   married    primary      no    66653      no   no
# 19420   59        admin.   married    unknown      no    64343      no   no
# 41374   32  entrepreneur    single   tertiary      no    59649      no   no
# 12926   56   blue-collar   married  secondary      no    58932      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %% [markdown]
# # Display the Bottom 10 Customers with the Lowest Balance

# %%
print(df.nsmallest(10, "balance"))
# Out:
#        age            job   marital  education default  balance housing loan  \
# 12909   26    blue-collar    single  secondary     yes    -8019      no  yes
# 15682   49     management   married   tertiary     yes    -6847      no  yes
# 38736   60     management  divorced   tertiary      no    -4057     yes   no
# 7413    43     management   married   tertiary     yes    -3372     yes   no
# 1896    57  self-employed   married   tertiary     yes    -3313     yes  yes
# 32713   39  self-employed   married   tertiary      no    -3058     yes  yes
# 18573   40     technician   married   tertiary     yes    -2827     yes  yes
# 31509   52     management   married   tertiary      no    -2712     yes  yes
# 25119   49    blue-collar    single    primary     yes    -2604     yes   no
# 14434   51     management  divorced   tertiary      no    -2282     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %% [markdown]
# # Customer Age Distribution

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.hist(df["age"], bins=20, edgecolor="black")

plt.title("Customer Age Distribution")
plt.xlabel("Age")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# # Job-wise Customer Distribution

# %%
import matplotlib.pyplot as plt

df["job"].value_counts().plot(kind="bar", figsize=(10,5))

plt.title("Job-wise Customer Distribution")
plt.xlabel("Job")
plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# # Marital Status Distribution

# %%
import matplotlib.pyplot as plt

df["marital"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Marital Status Distribution")
plt.ylabel("")

plt.show()

# %% [markdown]
# # Education Level Analysis|

# %%
import matplotlib.pyplot as plt

df["education"].value_counts().plot(kind="bar")

plt.title("Education Level Analysis")
plt.xlabel("Education")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# # Housing Loan Distribution

# %%
import matplotlib.pyplot as plt

df["housing"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Housing Loan Distribution")
plt.ylabel("")

plt.show()

# %% [markdown]
# # Personal Loan Distribution

# %%
import matplotlib.pyplot as plt

df["loan"].value_counts().plot(kind="bar")

plt.title("Personal Loan Distribution")
plt.xlabel("Loan")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# # Contact Method Analysis

# %%
import matplotlib.pyplot as plt

df["contact"].value_counts().plot(kind="bar")

plt.title("Contact Method Used by Customers")
plt.xlabel("Contact Method")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# # Term Deposit Subscription Analysis

# %%
import matplotlib.pyplot as plt

df["y"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Term Deposit Subscription")
plt.ylabel("")

plt.show()

# %% [markdown]
# # Default Status Distribution

# %%
import matplotlib.pyplot as plt

df["default"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%"
)

plt.title("Customer Credit Default Status")
plt.ylabel("")
plt.show()
